# %% [markdown]
# # Notebook 00 - Data Scraping
# This notebook downloads the dataset directly from Kaggle using the API.
# **Prerequisites:** Place your `kaggle.json` token file in the root of this repository.

# %%
import os
import shutil
from pathlib import Path

# Defines a function to find the project root directory by looking for a specific marker (default is 'data')
def find_project_root(start=Path.cwd(), marker='data'): 
    current = start
    while current != current.parent:
        if (current / marker).exists():
            return current
        current = current.parent
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root() 
os.chdir(PROJECT_ROOT) # go to the root of the project

# %%
# Import dependencies 
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy==2.3.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.3.2)
# Requirement already satisfied: pandas==2.3.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: scikit-learn==1.7.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.7.2)
# Requirement already satisfied: matplotlib==3.10.6 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.10.6)
# Requirement already satisfied: seaborn==0.13.2 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: opendatasets==0.1.22 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.1.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: scipy>=1.8.0 in ./venv/lib/python3.12/site-packages (from scikit-learn==1.7.2->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.12/site-packages (from scikit-learn==1.7.2->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.12/site-packages (from scikit-learn==1.7.2->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib==3.10.6->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from opendatasets==0.1.22->-r requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: kaggle in ./venv/lib/python3.12/site-packages (from opendatasets==0.1.22->-r requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from opendatasets==0.1.22->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.3.3->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: bleach in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: jupytext in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (1.19.2)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.23 in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.1.23)
# Requirement already satisfied: protobuf in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (7.34.1)
# Requirement already satisfied: python-slugify in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (8.0.4)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (2.34.0)
# Requirement already satisfied: urllib3>=1.15.1 in ./venv/lib/python3.12/site-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.12/site-packages (from bleach->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in ./venv/lib/python3.12/site-packages (from jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in ./venv/lib/python3.12/site-packages (from jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: nbformat in ./venv/lib/python3.12/site-packages (from jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.12/site-packages (from jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in ./venv/lib/python3.12/site-packages (from python-slugify->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (3.14)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.12/site-packages (from requests->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (2026.4.22)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=1.0->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in ./venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./venv/lib/python3.12/site-packages (from nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in ./venv/lib/python3.12/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets==0.1.22->-r requirements.txt (line 6)) (4.15.0)

# %%
import opendatasets as od

od.download("https://www.kaggle.com/datasets/meetnagadia/amazon-kindle-book-review-for-sentiment-analysis", data_dir='data/dataframes/bronze')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Dataset URL: https://www.kaggle.com/datasets/meetnagadia/amazon-kindle-book-review-for-sentiment-analysis
# Downloading amazon-kindle-book-review-for-sentiment-analysis.zip to data/dataframes/bronze/amazon-kindle-book-review-for-sentiment-analysis
# 100%|██████████| 6.38M/6.38M [00:01<00:00, 5.89MB/s]
